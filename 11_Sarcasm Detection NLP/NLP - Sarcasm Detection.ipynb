# %% [markdown]
# ## Sarcasm Detection
#
# ## Description:
#
# Past studies in Sarcasm Detection mostly make use of Twitter datasets collected using hashtag based
# supervision but such datasets are noisy in terms of labels and language. Furthermore, many tweets are
# replies to other tweets and detecting sarcasm in these requires the availability of contextual tweets.
# In this hands-on project, the goal is to build a model to detect whether a sentence is sarcastic or not, using
# Bidirectional LSTMs.
#
#
# ## Reference:
# https://github.com/rishabhmisra/News-Headlines-Dataset-For-Sarcasm-Detection

# %% [markdown]
# ## Import Packages

# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Setting the current working directory
import os; 
os.chdir('/content/drive/MyDrive/GL/NLP')

# %%
import pandas as pd
import numpy as np

# %%
def parseJson(fname):
    for line in open(fname, 'r'):
        yield eval(line)

# %%
data = pd.read_json('/content/drive/MyDrive/GL/NLP/Data/Sarcasm_Headlines_Dataset.json', lines = True)
print(f'Data has {data.shape[0]} rows and {data.shape[1]} columns. Here are the first five rows of the data...')
display(data.head())
# Out:
# Data has 26709 rows and 3 columns. Here are the first five rows of the data...
#                                         article_link  ... is_sarcastic
# 0  https://www.huffingtonpost.com/entry/versace-b...  ...            0
# 1  https://www.huffingtonpost.com/entry/roseanne-...  ...            0
# 2  https://local.theonion.com/mom-starting-to-fea...  ...            1
# 3  https://politics.theonion.com/boehner-just-wan...  ...            1
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...  ...            0
#
# [5 rows x 3 columns]

# %%
data = list(parseJson('/content/drive/MyDrive/GL/NLP/Data/Sarcasm_Headlines_Dataset.json'))

# %%
df = pd.DataFrame(data)

# %%
df.head(10)
# Out:
#                                         article_link  ... is_sarcastic
# 0  https://www.huffingtonpost.com/entry/versace-b...  ...            0
# 1  https://www.huffingtonpost.com/entry/roseanne-...  ...            0
# 2  https://local.theonion.com/mom-starting-to-fea...  ...            1
# 3  https://politics.theonion.com/boehner-just-wan...  ...            1
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...  ...            0
# 5  https://www.huffingtonpost.com/entry/advancing...  ...            0
# 6  https://www.huffingtonpost.com/entry/how-meat-...  ...            0
# 7  https://www.huffingtonpost.com/entry/boxed-col...  ...            0
# 8  https://politics.theonion.com/top-snake-handle...  ...            1
# 9  https://www.huffingtonpost.com/entry/fridays-m...  ...            0
#
# [10 rows x 3 columns]

# %% [markdown]
# ## Drop one column

# %%
df_1 = df.drop('article_link', axis=1)

# %%
df_1.head()
# Out:
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %% [markdown]
# ## Get length of each sentence

# %%
df_1['col_length'] = df_1['headline'].apply(lambda x: len(x))

# %%
df_1['headline'][0]
# Out:
# "former versace store clerk sues over secret 'black code' for minority shoppers"

# %%
df_1.head()
# Out:
#                                             headline  is_sarcastic  col_length
# 0  former versace store clerk sues over secret 'b...             0          78
# 1  the 'roseanne' revival catches up to our thorn...             0          84
# 2  mom starting to fear son's web series closest ...             1          79
# 3  boehner just wants wife to listen, not come up...             1          84
# 4  j.k. rowling wishes snape happy birthday in th...             0          64

# %% [markdown]
# ## Apply tensorflow.keras Tokenizer and get indices for words.

# %%
max_features = 10000
maxlen = 25
embedding_size = 200

# %%
headline_data = df_1['headline']

# Splitting the dataset into Train and Test
training_size = round(len(headline_data) * .75)

hl_data_train_sent = headline_data[0:training_size]
hl_data_test_sent = headline_data[training_size:]

labels = df_1['is_sarcastic']
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer=Tokenizer(num_words=10000)

# fit on the input data 
tokenizer.fit_on_texts(hl_data_train_sent)

# %%
train_sequences = tokenizer.texts_to_sequences(hl_data_train_sent)
test_sequences = tokenizer.texts_to_sequences(hl_data_test_sent)

# %%
print(train_sequences)
print(test_sequences)
# Out:
# [[327, 800, 3411, 2408, 46, 388, 2217, 5, 2621, 8873], [3, 6844, 3100, 3101, 22, 1, 161, 389, 2842, 5, 250, 8, 889], [152, 890, 1, 891, 1447, 2218, 595, 5659, 217, 132, 36, 44, 1, 8874], [1252, 37, 212, 382, 1, 1574, 28, 287, 22, 9, 2409, 1448, 5660, 958], [716, 671, 5661, 1042, 8875, 661, 552, 4, 3, 91, 1253, 89], [8876, 3, 366, 69], [3, 6845, 369, 5, 491, 3412, 1877, 1379], [19, 563, 36, 1091, 30, 163, 1, 102, 86, 17, 149, 5, 32, 344], [277, 3413, 6846, 447, 8877, 2092, 147], [2093, 299, 335, 370, 62, 5, 3, 4268], [3102, 2219, 3759, 13, 35, 5662, 8878, 4, 2094, 1092], [300, 767, 427, 7, 1667, 1668, 8, 3103], [221, 477, 2843, 12, 8, 922, 238, 371, 1, 4269, 6847], [236, 5663, 8879, 3760, 38, 239, 5, 6, 174], [1380, 801, 662, 4, 336, 2, 959], [526, 2094, 8880, 126, 8881, 5, 8882, 3761, 1669], [2095, 1329, 340, 45, 3414, 322, 287, 960, 1, 21, 18, 1043, 358, 108, 1449], [1670, 6848, 3104, 8883, 18, 5664, 1203], [8884, 821, 1, 1767, 250, 1204, 37, 210, 2410], [4828, 4829, 3105], [8885, 3762, 802, 38, 1671, 8886, 5665], [12, 1254, 140, 24, 822, 5, 607, 4830, 1255, 20, 3415, 2411, 33, 32, 1575, 8887], [3416, 8888, 6849, 55, 35, 3106, 132, 73, 8, 5666], [19, 10, 45, 17, 1144, 178, 1, 3, 4831], [608, 478, 823, 3, 3107, 3417, 1205, 83, 824, 1989, 4270, 2, 8889], [45, 3763, 348, 189, 1, 21, 1450], [68, 1768, 231, 5667, 1, 1381, 2220], [543, 3764, 75, 345, 609], [20, 6850, 6851, 203, 1206, 690, 3418], [6852, 10, 3, 1672, 2, 3, 4832], [2412, 5668, 8890, 5, 738, 10, 3419], [7, 31, 100, 57, 1, 2622, 2221, 8891], [1451, 717, 1, 6853, 1330, 2623, 2, 20, 328], [739, 133, 44, 2413, 3765, 344, 1, 123], [448, 4833, 3108, 3766, 4, 1576], [86, 17, 182, 6, 578, 15, 3, 1331], [1207, 4271, 1332, 596], [8892, 663, 1, 3, 277, 2, 3, 610, 200, 9, 768, 8893, 209, 214, 961], [263, 174, 1452, 527, 3, 204, 1577, 2, 390], [3109, 923, 8894, 7, 564, 5, 3767, 663, 41], [6854, 4834, 717, 1, 6855, 962, 2222, 2, 3420, 349], [672, 317, 1, 190, 3768, 1005, 740, 528, 65, 611, 19, 3110, 1878, 32, 66], [5669, 5670, 232, 6856, 3421, 75, 42, 1769], [8895, 1382, 1673, 1333, 14, 183, 8896], [244, 3, 664, 2, 612, 19, 564, 246], [803, 6857, 1768, 3769, 5671, 647], [1879, 2223, 24, 2414, 4835, 228, 116, 963, 69, 492, 39, 5, 137, 228], [6858, 1, 247, 66, 4, 1498, 3422, 2096, 71, 3111, 1, 2624], [892, 64, 855, 1880, 1770, 10, 3423], [3112, 18, 259, 856], [4272, 769, 8897, 2224], [209, 169, 112, 1578, 4, 253, 15, 633, 87, 1383, 4, 1330], [2625, 409, 3770, 254, 1384, 6, 329, 3771, 66], [49, 12, 4271, 5, 6, 595, 2, 509, 4, 3, 6859, 1385, 138], [49, 12, 1990, 44, 260, 3, 410, 1771, 1, 185, 5672, 264, 147, 1674, 4836], [11, 1093, 1772, 293, 402, 201, 8898, 804, 493, 390], [5673, 23, 2, 205, 8899, 4, 5674, 5, 428], [4837, 179, 1499, 419, 7, 175, 2626, 462, 78], [634, 341, 597, 162, 5675, 2627, 4, 691, 4838], [25, 1, 1044, 1453, 1094, 206, 3, 84, 19, 360, 2844], [68, 38, 2225], [2226, 201, 4, 4839, 1773], [6860, 420, 11, 4, 3772, 449, 6861], [43, 158, 6862, 1256, 103, 8900, 8901, 510, 2, 1386, 411, 125, 6863], [2628, 122, 76, 6, 964, 1579, 2, 924, 254, 265, 2845, 23], [8902, 36, 176, 2415, 5676, 14, 494, 2629, 4840], [40, 2, 3, 91, 692, 1145, 5, 195, 65, 6864, 323], [25, 301, 925, 145, 32, 248, 1, 3, 204, 1095, 18, 5677, 4, 1, 3, 8903], [47, 55, 1045, 528, 8904], [438, 5678, 926, 5, 1675, 4, 4841], [221, 2227, 28, 1257, 14, 4, 613], [187, 703, 741, 2228, 273, 16, 313, 8, 372], [693, 6865, 330, 22, 1, 8905, 15, 169, 318], [31, 10, 648, 54, 578, 6866, 117, 57], [3, 6867, 2, 691, 3, 1454, 2846, 3773, 4, 161, 56], [19, 553, 331, 88, 52, 1500, 3, 965, 18, 1258, 1096], [2097, 4842, 278, 1, 1259, 893, 4, 4843], [12, 1006, 1881, 7, 691, 4, 6868, 5, 2630, 302], [8906, 1991, 6, 6869, 479], [41, 2229, 25, 27, 116, 232, 2621, 240], [1387, 5679, 1208, 3113, 1, 195, 1046, 24, 805], [2847, 3114, 3115, 565, 1047, 4273, 123], [8907, 6870, 1455, 5680, 15, 857, 4844, 14, 8908, 42, 4274], [314, 704, 966, 3, 84, 24, 3774, 5, 3, 596, 10, 4845, 3424], [193, 41, 58, 6871, 80, 649, 6872, 4846, 169, 18, 64], [54 ...
# [[882, 3, 1266, 1758], [84, 3285, 1629, 64, 37, 269, 1, 59, 601, 1178, 337, 2, 142, 1436, 5], [10, 5012, 4], [3192, 7934, 185, 5830, 20, 3589, 1033, 126, 1867, 605], [139, 5, 924, 7032], [702, 2, 6060, 2, 690, 3550, 42, 600, 14, 3208, 3209], [956, 398, 338, 2798, 50, 39, 77, 497, 3, 130, 10, 199], [114, 2160, 167, 3, 1726, 453, 4357, 226, 4357], [1269, 381, 843, 2120], [140, 5, 412, 6907, 1732], [2579, 9083, 3722, 112, 7, 47, 216], [3270, 2499, 6896, 16], [12, 162, 99, 3384, 71, 949, 107, 23, 2, 1086], [2112, 167, 692, 992, 7, 8113, 2, 69, 2, 1048, 15, 582, 545], [7304, 881, 23, 1677, 5066, 508], [3, 91, 1536, 5, 2614, 798, 4, 3, 48, 53], [284, 198, 44, 27, 33], [179, 1238, 5, 2638, 397, 737], [1339, 903, 50, 1338, 2966, 14, 258, 71, 28, 3, 2624], [36, 32, 896, 26, 640, 1918, 203, 5, 2773, 1550], [1451, 7089, 207, 9, 46, 185, 899, 1551], [3565, 3159, 5, 13, 1653, 325, 1813, 26, 452], [409, 4246, 14, 8001, 46, 72, 7036, 2871, 50, 100], [703, 14, 30, 375, 185], [19, 3899, 4756, 37, 224, 27, 1, 69], [169, 18, 799, 2, 863, 1852, 4, 5162], [13, 6126, 18, 1249, 2078, 753, 1791, 114, 104, 460, 1033], [295, 443, 2, 85, 224, 4, 571], [8609, 1310, 104, 217, 2775, 2197, 539], [1771, 5186, 5518, 1275, 1435, 262, 127], [31, 30, 1726, 236, 301, 80, 17], [2180, 8, 615, 7751, 1494, 443, 14, 90, 2591, 4, 5988], [3, 217, 30, 1726, 52, 96, 174, 495, 3095], [241, 518, 7225, 517, 5, 3, 745, 350], [327, 170, 1295, 128, 11, 624, 26, 3565, 327, 1295], [1560, 238, 2561, 1221, 537], [634, 1558, 7, 1311, 20, 302, 133, 21, 7797, 5040], [2465, 708, 1827, 4613, 2, 4, 954, 902], [49, 12, 361, 20, 5, 6399, 32, 235, 1106], [1224, 4, 7345, 7346, 6502, 5518], [72, 70, 1562, 207, 7, 7962], [160, 45, 69, 1144, 21, 3260, 1, 556, 5, 6, 1390], [8300, 1134, 590, 3352, 9, 194, 4941, 363, 946], [290, 540, 1230, 123, 1696, 5, 15, 49, 12, 1086], [47, 152, 3583, 506, 41, 58, 566, 116, 21, 1535, 18, 64, 86, 132, 37, 60, 646, 39], [3, 778, 40, 3836, 1, 7199, 5, 3, 3088, 1648], [499, 6, 338, 103, 19, 590, 3, 328, 1026, 161, 459, 522], [685, 165, 9592, 42, 175, 862], [1030, 4974, 141, 1, 972], [104, 56, 485, 38, 230, 1056, 227, 10, 80, 1487, 3898], [45, 10, 6, 3792, 1237, 486, 3, 4947, 2], [24, 3342, 2475], [1287, 843, 3318, 121, 20, 4577, 27, 4, 4571], [623, 13, 387, 20, 1869, 22, 5, 199, 332, 138], [2313, 2570, 1423, 23, 7, 2239, 1248, 1193], [1873, 230, 33, 452, 1280, 5], [36, 19, 21, 3, 571, 1648], [789, 211, 4035, 2190, 23, 2, 290], [2526, 5, 1492, 1605], [93, 1045, 499, 2731, 353, 17, 7006, 4713, 1578, 17, 122, 178, 1, 3, 1278, 4112], [115, 247, 1969, 492, 51, 1086, 9, 6261, 15, 267, 888], [426, 206, 4], [1219, 144, 444, 17, 367], [223, 1744, 738, 453, 1, 2104], [2549, 7510, 2411, 25, 2195, 27, 116, 21, 86, 93, 33, 1140, 144, 26, 5669, 4419], [5767, 8697, 3, 104, 127, 85, 343, 960, 1, 4, 2201], [1406, 454, 250, 77, 230, 4, 779, 147], [5555, 55, 1042, 3045, 5134, 1322, 116, 178, 5, 60, 402, 4, 6, 174], [3607, 3218, 1153, 11, 1136, 24, 9724, 868, 2, 4, 1701, 705], [79, 1532, 68, 5, 5038], [31, 19, 222, 3907, 80, 34, 712, 7, 3, 75, 5], [1619, 274, 846, 506, 143, 633, 2700], [11, 5064, 886, 2, 2178, 3095, 7, 666], [45, 62, 2066, 8, 3794, 1, 32], [1378, 48, 53, 1810, 1045, 1, 44, 239, 3547, 8528, 501, 783, 1336], [4757, 8, 5393], [937, 330, 22, 814, 874, 72], [860, 68, 844, 616, 1018, 95], [13, 28, 1, 1785, 2866, 14, 1798, 18, 535, 538], [2307, 6922, 4885, 5330, 186, 4450, 2, 79, 7843], [47, 13, 117, 7, 136, 408, 91, 2, 4480, 5486, 5, 1105, 51], [2134, 2016, 485, 1118, 1814, 78, 18, 1069], [1757, 2, 6, 977, 282, 3679, 126, 1160], [211, 72, 70, 211, 7261, 254, 81, 1469], [58, 2388, 18, 1434, 3148, 64, 6, 292, 2], [1858, 268, 3633, 3017, 8], [115, 64, 4361, 4730], [97, 167, 129, 7, 5954, 2490, 1, 1420, 2275, 1667, 101], [4274, 4, 870, 1829, 37, 4, 56, 5, 4600], [2664, 3818, 1241, 383, 1, 2720, 9, 1073, 633, 7, 293, 536], [92, 7, 378, 641, 1, 1005, 1498], [390, 516, 26, 677, 856, 7, 3695, 25, 27, 36, 7379], [7911, 853, 8756, 3, 2784, 23, 2, 933], [1953, 7079, 293, 2508, 643, 61 ...

# %% [markdown]
# ## Pad sequences

# %%
from keras.preprocessing.sequence import pad_sequences

hl_train_data_pad = pad_sequences(train_sequences, maxlen = maxlen)  #makes all the array the same length by filling out with 0x
hl_test_data_pad = pad_sequences(test_sequences, maxlen = maxlen)

# %% [markdown]
# ## Vocab mapping

# %%
tokenizer.word_index
# Out:
# {'to': 1,
#  'of': 2,
#  'the': 3,
#  'in': 4,
#  'for': 5,
#  'a': 6,
#  'on': 7,
#  'and': 8,
#  'with': 9,
#  'is': 10,
#  'new': 11,
#  'trump': 12,
#  'man': 13,
#  'from': 14,
#  'at': 15,
#  'about': 16,
#  'you': 17,
#  'by': 18,
#  'this': 19,
#  'after': 20,
#  'be': 21,
#  'up': 22,
#  'out': 23,
#  'that': 24,
#  'how': 25,
#  'as': 26,
#  'it': 27,
#  'not': 28,
#  'are': 29,
#  'your': 30,
#  'what': 31,
#  'his': 32,
#  'all': 33,
#  'he': 34,
#  'who': 35,
#  'will': 36,
#  'just': 37,
#  'has': 38,
#  'more': 39,
#  'one': 40,
#  'year': 41,
#  'into': 42,
#  'report': 43,
#  'have': 44,
#  'why': 45,
#  'over': 46,
#  'area': 47,
#  'u': 48,
#  'donald': 49,
#  'says': 50,
#  'day': 51,
#  'can': 52,
#  's': 53,
#  'first': 54,
#  'woman': 55,
#  'time': 56,
#  'like': 57,
#  'old': 58,
#  'get': 59,
#  'her': 60,
#  'no': 61,
#  "trump's": 62,
#  'off': 63,
#  'now': 64,
#  'an': 65,
#  'life': 66,
#  'people': 67,
#  'obama': 68,
#  'women': 69,
#  'house': 70,
#  "'": 71,
#  'white': 72,
#  'was': 73,
#  'still': 74,
#  'back': 75,
#  'make': 76,
#  'than': 77,
#  'down': 78,
#  'clinton': 79,
#  'when': 80,
#  'my': 81,
#  '5': 82,
#  'could': 83,
#  'world': 84,
#  'americans': 85,
#  'if': 86,
#  'i': 87,
#  'we': 88,
#  'way': 89,
#  'their': 90,
#  'most': 91,
#  'study': 92,
#  'they': 93,
#  'before': 94,
#  'family': 95,
#  'do': 96,
#  'gop': 97,
#  'best': 98,
#  'black': 99,
#  "it's": 100,
#  'bill': 101,
#  'school': 102,
#  'but': 103,
#  'only': 104,
#  'police': 105,
#  'so': 106,
#  'him': 107,
#  'years': 108,
#  'president': 109,
#  'know': 110,
#  'should': 111,
#  '3': 112,
#  'last': 113,
#  'being': 114,
#  'watch': 115,
#  'would': 116,
#  'really': 117,
#  '10': 118,
#  'video': 119,
#  'going': 120,
#  'show': 121,
#  "can't": 122,
#  'death': 123,
#  'hillary': 124,
#  'american': 125,
#  'during': 126,
#  'things': 127,
#  'finds': 128,
#  'good': 129,
#  'state': 130,
#  'against': 131,
#  'she': 132,
#  'may': 133,
#  'home': 134,
#  'or': 135,
#  'love': 136,
#  'health': 137,
#  'say': 138,
#  'need': 139,
#  'nation': 140,
#  'too': 141,
#  'every': 142,
#  '000': 143,
#  'right': 144,
#  'take': 145,
#  'gets': 146,
#  'campaign': 147,
#  "'the": 148,
#  'work': 149,
#  'little': 150,
#  '2': 151,
#  'mom': 152,
#  'some': 153,
#  'court': 154,
#  'getting': 155,
#  'party': 156,
#  'high': 157,
#  'john': 158,
#  '7': 159,
#  "here's": 160,
#  'our': 161,
#  'calls': 162,
#  'kids': 163,
#  'where': 164,
#  'takes': 165,
#  'parents': 166,
#  'makes': 167,
#  'child': 168,
#  'dead': 169,
#  'big': 170,
#  'these': 171,
#  'election': 172,
#  'local': 173,
#  'while': 174,
#  'own': 175,
#  'never': 176,
#  'real': 177,
#  'go': 178,
#  'news': 179,
#  "doesn't": 180,
#  'other': 181,
#  'see': 182,
#  "he's": 183,
#  'america': 184,
#  'self': 185,
#  'through': 186,
#  '4': 187,
#  'want': 188,
#  'plan': 189,
#  'stop': 190,
#  'college': 191,
#  'guy': 192,
#  '6': 193,
#  'its': 194,
#  'change': 195,
#  'look': 196,
#  'sex': 197,
#  "don't": 198,
#  'gay': 199,
#  'office': 200,
#  'again': 201,
#  'two': 202,
#  'bush': 203,
#  'next': 204,
#  "nation's": 205,
#  'around': 206,
#  'war': 207,
#  'even': 208,
#  '1': 209,
#  'got': 210,
#  'another': 211,
#  'wants': 212,
#  'baby': 213,
#  'million': 214,
#  'long': 215,
#  "man's": 216,
#  'thing': 217,
#  'dog': 218,
#  'them': 219,
#  'week': 220,
#  'north': 221,
#  'dad': 222,
#  'congress': 223,
#  'made': 224,
#  'gun': 225,
#  'much': 226,
#  'job': 227,
#  'care': 228,
#  'under': 229,
#  'ever': 230,
#  'national': 231,
#  'help': 232,
#  'finally': 233,
#  '20': 234,
#  'debate': 235,
#  'actually': 236,
#  'ways': 237,
#  'us': 238,
#  'been': 239,
#  'students': 240,
#  '9': 241,
#  'shows': 242,
#  'sexual': 243,
#  'give': 244,
#  "won't": 245,
#  'season': 246,
#  'live': 247,
#  'game': 248,
#  'making': 249,
#  'better': 250,
#  'climate': 251,
#  'senate': 252,
#  'shooting': 253,
#  'without': 254,
#  'anti': 255,
#  'history': 256,
#  'media': 257,
#  'god': 258,
#  'night': 259,
#  'had': 260,
#  'star': 261,
#  'couple': 262,
#  'money': 263,
#  'entire': 264,
#  'everyone': 265,
#  'there': 266,
#  'city': 267,
#  'free': 268,
#  'trying': 269,
#  'any': 270,
#  'end': 271,
#  'law': 272,
#  'me': 273,
#  'children': 274,
#  'announces': 275,
#  'tv': 276,
#  'top': 277,
#  'found': 278,
#  'away': 279,
#  'paul': 280,
#  'supreme': 281,
#  'face': 282,
#  '8': 283,
#  'men': 284,
#  'government': 285,
#  'teen': 286,
#  'come': 287,
#  'story': 288,
#  'tell': 289,
#  'business': 290,
#  'food': 291,
#  'part': 292,
#  'film': 293,
#  'bad': 294,
#  'reveals': 295,
#  'introduces': 296,
#  'think': 297,
#  'deal': 298,
#  'morning': 299,
#  'facebook': 300,
#  'does': 301,
#  'attack': 302,
#  'find': 303,
#  'james': 304,
#  'movie': 305,
#  'son': 306,
#  'car': 307,
#  'friend': 308,
#  'york': 309,
#  '11': 310,
#  'enough': 311,
#  'fire': 312,
#  'power': 313,
#  'pope': 314,
#  'fight': 315,
#  'wedding': 316,
#  'used': 317,
#  'body': 318,
#  'book': 319,
#  'call': 320,
#  'middle': 321,
#  "didn't": 322,
#  'girl': 323,
#  'run': 324,
#  'same': 325,
#  'use': 326,
#  'former': 327,
#  'tax': 328,
#  'single': 329,
#  'line': 330,
#  'thinks': 331,
#  'friends': 332,
#  'public': 333,
#  'second': 334,
#  'email': 335,
#  'support': 336,
#  'photos': 337,
#  'republican': 338,
#  'great': 339,
#  'asks': 340,
#  'rights': 341,
#  'sanders': 342,
#  'looking': 343,
#  'company': 344,
#  'behind': 345,
#  'marriage': 346,
#  'speech': 347,
#  'must': 348,
#  'claims': 349,
#  'room': 350,
#  'security': 351,
#  'already': 352,
#  'because': 353,
#  'each': 354,
#  '2016': 355,
#  'keep': 356,
#  'judge': 357,
#  'team': 358,
#  'republicans': 359,
#  'christmas': 360,
#  'goes': 361,
#  'vote': 362,
#  'presidential': 363,
#  'democrats': 364,
#  'talk': 365,
#  "world's": 366,
#  'might': 367,
#  'violence': 368,
#  'case': 369,
#  'inside': 370,
#  'voters': 371,
#  'control': 372,
#  'open': 373,
#  'ban': 374,
#  'future': 375,
#  'name': 376,
#  'win': 377,
#  'human': 378,
#  'department': 379,
#  'between': 380,
#  'ad': 381,
#  'wife': 382,
#  'coming': 383,
#  'perfect': 384,
#  'having': 385,
#  'twitter': 386,
#  'killed': 387,
#  'secret': 388,
#  'political': 389,
#  'fans': 390,
#  'full': 391,
#  'sure': 392,
#  'group': 393,
#  'very': 394,
#  'pretty': 395,
#  'student': 396,
#  '12': 397,
#  'texas': 398,
#  'three': 399,
#  'bernie': 400,
#  'record': 401,
#  'once': 402,
#  'music': 403,
#  '15': 404,
#  'missing': 405,
#  'releases': 406,
#  'poll': 407,
#  'doing': 408,
#  'teacher': 409,
#  'ready': 410,
#  'living': 411,
#  'super': 412,
#  'boy': 413,
#  'always': 414,
#  'scientists': 415,
#  'meet': 416,
#  'art': 417,
#  'here': 418,
#  'reports': 419,
#  'unveils': 420,
#  'save': 421,
#  'kim': 422,
#  'until': 423,
#  'photo': 424,
#  'race': 425,
#  'something': 426,
#  'working': 427,
#  'summer': 428,
#  'comes': 429,
#  'were': 430,
#  'fucking': 431,
#  'post': 432,
#  'obamacare': 433,
#  'shot': 434,
#  'start': 435,
#  'word': 436,
#  'running': 437,
#  'ryan': 438,
#  'california': 439,
#  'lives': 440,
#  'month': 441,
#  'mike': 442,
#  'thousands': 443,
#  'gives': 444,
#  'days': 445,
#  'wall': 446,
#  'leaves': 447,
#  'drug': 448,
#  'water': 449,
#  'head': 450,
#  'class': 451,
#  'female': 452,
#  'age': 453,
#  'looks': 454,
#  'social': 455,
#  'minutes': 456,
#  'many': 457,
#  'let': 458,
#  'country': 459,
#  'person': 460,
#  'put': 461,
#  'breaking': 462,
#  'everything': 463,
#  'father': 464,
#  'plans': 465,
#  'russia': 466,
#  'states': 467,
#  'town': 468,
#  'candidate': 469,
#  'forced': 470,
#  'tells': 471,
#  'cancer': 472,
#  'yet': 473,
#  'education': 474,
#  'left': 475,
#  'probably': 476,
#  'korea': 477,
#  'cruz': 478,
#  'dream': 479,
#  "'i": 480,
#  'air': 481,
#  'place': 482,
#  'past': 483,
#  'admits': 484,
#  'employee': 485,
#  'taking': 486,
#  'hot': 487,
#  'believe': 488,
#  'biden': 489,
#  'did': 490,
#  'eating': 491,
#  'pay': 492,
#  'hard': 493,
#  'red': 494,
#  "you're": 495,
#  'mother': 496,
#  'half': 497,
#  'street': 498,
#  "i'm": 499,
#  'justice': 500,
#  'secretary': 501,
#  'beautiful': 502,
#  'guide': 503,
#  'romney': 504,
#  'administration': 505,
#  '30': 506,
#  'south': 507,
#  'heart': 508,
#  'wins': 509,
#  'list': 510,
#  'dies': 511,
#  'military': 512,
#  '50': 513,
#  'isis': 514,
#  'internet': 515,
#  'excited': 516,
#  'tips': 517,
#  'personal': 518,
#  'small': 519,
#  'young': 520,
#  'talks': 521,
#  'needs': 522,
#  'together': 523,
#  'fbi': 524,
#  'rock': 525,
#  'nuclear': 526,
#  'lost': 527,
#  'times': 528,
#  'questions': 529,
#  'michael': 530,
#  'fan': 531,
#  'lot': 532,
#  'those': 533,
#  'letter': 534,
#  'hollywood': 535,
#  'set': 536,
#  'crisis': 537,
#  'officials': 538,
#  'king': 539,
#  'owner': 540,
#  'latest': 541,
#  'idea': 542,
#  'ex': 543,
#  'thought': 544,
#  'march': 545,
#  'kill': 546,
#  'restaurant': 547,
#  'iran': 548,
#  'director': 549,
#  'warns': 550,
#  'chris': 551,
#  'birthday': 552,
#  'congressman': 553,
#  "what's": 554,
#  'issues': 555,
#  'ask': 556,
#  'wrong': 557,
#  'service': 558,
#  'system': 559,
#  'birth': 560,
#  'federal': 561,
#  'sleep': 562,
#  'ceo': 563,
#  'holiday': 564,
#  'following': 565,
#  'daughter': 566,
#  'celebrates': 567,
#  'move': 568,
#  'assault': 569,
#  'mark': 570,
#  'china': 571,
#  'third': 572,
#  'rise': 573,
#  'ice': 574,
#  'someone': 575,
#  'majority': 576,
#  'cat': 577,
#  'muslim': 578,
#  'giving': 579,
#  'phone': 580,
#  'fun': 581,
#  "women's": 582,
#  'problem': 583,
#  'abortion': 584,
#  'special': 585,
#  'wearing': 586,
#  'buy': 587,
#  'trip': 588,
#  'knows': 589,
#  "isn't": 590,
#  'tweets': 591,
#  'less': 592,
#  'nothing': 593,
#  'girls': 594,
#  'series': 595,
#  'earth': 596,
#  'chief': 597,
#  'percent': 598,
#  'favorite': 599,
#  'washington': 600,
#  'few': 601,
#  'cover': 602,
#  'today': 603,
#  'talking': 604,
#  'meeting': 605,
#  'online': 606,
#  'syrian': 607,
#  'ted': 608,
#  'bar': 609,
#  'box': 610,
#  'hour': 611,
#  'play': 612,
#  'hours': 613,
#  'fashion': 614,
#  'late': 615,
#  'outside': 616,
#  'fox': 617,
#  'al': 618,
#  'community': 619,
#  'minute': 620,
#  'using': 621,
#  'message': 622,
#  'florida': 623,
#  'career': 624,
#  'become': 625,
#  'kid': 626,
#  'moment': 627,
#  'adorable': 628,
#  'huffpost': 629,
#  'watching': 630,
#  'stephen': 631,
#  'break': 632,
#  't': 633,
#  'un': 634,
#  '2015': 635,
#  'democratic': 636,
#  'shit': 637,
#  'offers': 638,
#  'thinking': 639,
#  'george': 640,
#  'response': 641,
#  'read': 642,
#  'weekend': 643,
#  'months': 644,
#  'visit': 645,
#  'hair': 646,
#  'victims': 647,
#  "america's": 648,
#  'told': 649,
#  'hope': 650,
#  'least': 651,
#  'different': 652,
#  'point': 653,
#  'travel': 654,
#  'front': 655,
#  'billion': 656,
#  'since': 657,
#  'rules': 658,
#  'russian': 659,
#  'feel': 660,
#  'happy': 661,
#  'protest': 662,
#  'straight': 663,
#  'gift': 664,
#  'union': 665,
#  'bus': 666,
#  'crash': 667,
#  "she's": 668,
#  'anything': 669,
#  'dating': 670,
#  'k': 671,
#  'scott': 672,
#  'david': 673,
#  'accused': 674,
#  "obama's": 675,
#  'taylor': 676,
#  'trailer': 677,
#  'kind': 678,
#  'names': 679,
#  'well': 680,
#  'key': 681,
#  'order': 682,
#  'true': 683,
#  'reasons': 684,
#  'cop': 685,
#  'pence': 686,
#  'reason': 687,
#  'joe': 688,
#  'dinner': 689,
#  'oil': 690,
#  'syria': 691,
#  'powerful': 692,
#  'sick': 693,
#  '100': 694,
#  'brings': 695,
#  'global': 696,
#  'date': 697,
#  'lead': 698,
#  'policy': 699,
#  'spends': 700,
#  'learned': 701,
#  'millions': 702,
#  'lessons': 703,
#  'francis': 704,
#  'c': 705,
#  'struggling': 706,
#  'low': 707,
#  'discover': 708,
#  'song': 709,
#  'opens': 710,
#  'far': 711,
#  'himself': 712,
#  'girlfriend': 713,
#  'conversation': 714,
#  'schools': 715,
#  'j': 716,
#  'vows': 717,
#  'worried': 718,
#  'leave': 719,
#  'surprise': 720,
#  'kills': 721,
#  'united': 722,
#  'hate': 723,
#  'leader': 724,
#  'nfl': 725,
#  'oscar': 726,
#  'style': 727,
#  'whole': 728,
#  'anniversary': 729,
#  'turns': 730,
#  'hit': 731,
#  'waiting': 732,
#  'general': 733,
#  'fighting': 734,
#  'host': 735,
#  'immigration': 736,
#  '2017': 737,
#  'killing': 738,
#  'apple': 739,
#  '40': 740,
#  'prison': 741,
#  '2014': 742,
#  'adds': 743,
#  'drunk': 744,
#  'weight': 745,
#  "they're": 746,
#  'd': 747,
#  'near': 748,
#  'rubio': 749,
#  'reality': 750,
#  'weird': 751,
#  'senator': 752,
#  'feels': 753,
#  'possible': 754,
#  'moving': 755,
#  'stars': 756,
#  'signs': 757,
#  'politics': 758,
#  'sign': 759,
#  'jr': 760,
#  'leaders': 761,
#  'stand': 762,
#  'called': 763,
#  'tour': 764,
#  'returns': 765,
#  'totally': 766,
#  'reportedly': 767,
#  'massive': 768,
#  'sports': 769,
#  'major': 770,
#  'force': 771,
#  'advice': 772,
#  'breaks': 773,
#  'number': 774,
#  'bring': 775,
#  'transgender': 776,
#  'west': 777,
#  'mass': 778,
#  'spring': 779,
#  'door': 780,
#  'fall': 781,
#  'investigation': 782,
#  'tom': 783,
#  'employees': 784,
#  'test': 785,
#  'return': 786,
#  'relationship': 787,
#  'important': 788,
#  'puts': 789,
#  'iowa': 790,
#  'stage': 791,
#  'murder': 792,
#  'candidates': 793,
#  'close': 794,
#  'magazine': 795,
#  'early': 796,
#  'trans': 797,
#  'attacks': 798,
#  'side': 799,
#  'store': 800,
#  'huge': 801,
#  'artist': 802,
#  'christian': 803,
#  'die': 804,
#  'abuse': 805,
#  'longer': 806,
#  'members': 807,
#  'worst': 808,
#  'peace': 809,
#  'loses': 810,
#  'act': 811,
#  'kardashian': 812,
#  'audience': 813,
#  'five': 814,
#  'steve': 815,
#  'sean': 816,
#  'suspect': 817,
#  'prince': 818,
#  'ben': 819,
#  'suicide': 820,
#  'program': 821,
#  'decision': 822,
#  'hits': 823,
#  'lose': 824,
#  'awards': 825,
#  'queer': 826,
#  'whether': 827,
#  'cops': 828,
#  'paris': 829,
#  'workers': 830,
#  'responds': 831,
#  'push': 832,
#  'fuck': 833,
#  'iraq': 834,
#  'google': 835,
#  'leaving': 836,
#  'carolina': 837,
#  'final': 838,
#  'voice': 839,
#  'chinese': 840,
#  '13': 841,
#  'lgbt': 842,
#  'executive': 843,
#  'seen': 844,
#  'jimmy': 845,
#  'given': 846,
#  'keeps': 847,
#  'shares': 848,
#  'industry': 849,
#  'biggest': 850,
#  'protesters': 851,
#  'results': 852,
#  'press': 853,
#  'center': 854,
#  'almost': 855,
#  'light': 856,
#  'risk': 857,
#  'asking': 858,
#  'emotional': 859,
#  'michelle': 860,
#  'male': 861,
#  'hands': 862,
#  'road': 863,
#  'bathroom': 864,
#  'allegations': 865,
#  'bowl': 866,
#  'begins': 867,
#  'planned': 868,
#  'homeless': 869,
#  'poor': 870,
#  'planet': 871,
#  'hoping': 872,
#  'governor': 873,
#  'non': 874,
#  'east': 875,
#  'fails': 876,
#  'cool': 877,
#  'wait': 878,
#  'moms': 879,
#  'humans': 880,
#  'cut': 881,
#  'mind': 882,
#  'defense': 883,
#  'pizza': 884,
#  'ferguson': 885,
#  'feeling': 886,
#  'amazon': 887,
#  'hall': 888,
#  'worse': 889,
#  'starting': 890,
#  'fear': 891,
#  'nasa': 892,
#  'problems': 893,
#  'check': 894,
#  'ebola': 895,
#  'role': 896,
#  'building': 897,
#  'arrested': 898,
#  'driving': 899,
#  'four': 900,
#  'scandal': 901,
#  'space': 902,
#  'moore': 903,
#  'science': 904,
#  'dance': 905,
#  'easy': 906,
#  'hand': 907,
#  'israel': 908,
#  'picture': 909,
#  'eyes': 910,
#  'voter': 911,
#  "there's": 912,
#  'mental': 913,
#  'action': 914,
#  'doctor': 915,
#  'spend': 916,
#  'spot': 917,
#  'board': 918,
#  'chance': 919,
#  'words': 920,
#  'suggests': 921,
#  'urges': 922,
#  'williams': 923,
#  'coffee': 924,
#  'green': 925,
#  'apologizes': 926,
#  'celebrate': 927,
#  'documentary': 928,
#  'supporters': 929,
#  'rest': 930,
#  'remember': 931,
#  'depression': 932,
#  'halloween': 933,
#  'deadly': 934,
#  'louis': 935,
#  'pro': 936,
#  'oscars': 937,
#  'interview': 938,
#  'park': 939,
#  'completely': 940,
#  'harassment': 941,
#  'card': 942,
#  'university': 943,
#  'success': 944,
#  'coworker': 945,
#  'pick': 946,
#  'harvey': 947,
#  'happens': 948,
#  'throws': 949,
#  'band': 950,
#  'pregnant': 951,
#  'hear': 952,
#  'crowd': 953,
#  'deep': 954,
#  'amazing': 955,
#  'official': 956,
#  'chicken': 957,
#  'ideas': 958,
#  'refugees': 959,
#  'forward': 960,
#  'opening': 961,
#  'reveal': 962,
#  'mean': 963,
#  'simple': 964,
#  'economy': 965,
#  'reminds': 966,
#  'which': 967,
#  'turn': 968,
#  'healthy': 969,
#  'senators': 970,
#  'swift': 971,
#  'eat': 972,
#  'hurricane': 973,
#  '17': 974,
#  'album': 975,
#  'despite': 976,
#  "woman's": 977,
#  'chicago': 978,
#  'movies': 979,
#  'happened': 980,
#  'officer': 981,
#  'across': 982,
#  'desperate': 983,
#  'uses': 984,
#  'apartment': 985,
#  'plane': 986,
#  'realizes': 987,
#  'funding': 988,
#  'holding': 989,
#  'leading': 990,
#  'crime': 991,
#  'demand': 992,
#  "we're": 993,
#  'try': 994,
#  'explains': 995,
#  'historical': 996,
#  'seeing': 997,
#  'slams': 998,
#  'residents': 999,
#  'sales': 1000,
#  ...}

# %% [markdown]
# ## Set number of words

# %%
num_words = len(tokenizer.word_index) + 1
print(num_words)
# Out:
# 25652

# %% [markdown]
# ## Load Glove Word Embeddings

# %%
path = '/content/drive/MyDrive/GL/NLP/Data/'

glove_file = path + 'glove.6B.50d.txt'

# %% [markdown]
# ## Create embedding matrix

# %%
embeddings_index = {}
f = open(glove_file)
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %% [markdown]
# ## Define model

# %%
EMBEDDING_FILE = path + 'glove.6B.300d.txt'

embeddings = {}
for o in open(EMBEDDING_FILE):
    word = o.split(" ")[0]
    # print(word)
    embd = o.split(" ")[1:]
    embd = np.asarray(embd, dtype='float32')
    # print(embd)
    embeddings[word] = embd

# create a weight matrix for words in training docs
embedding_matrix = np.zeros((num_words, 300))

for word, i in tokenizer.word_index.items():
	embedding_vector = embeddings.get(word)
	if embedding_vector is not None:
		embedding_matrix[i] = embedding_vector

# %%
from keras import models
from keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Dense, Embedding, LSTM,TimeDistributed, SpatialDropout1D, Bidirectional
model = models.Sequential()
embedding_dim = 300 
#e = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=4, trainable=False)
#model.add(Embedding(max_features, embedding_dim, input_length=maxlen))
model.add(Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=maxlen))
model.add(Bidirectional(LSTM(units=60, activation='tanh',return_sequences=True)))
model.add(TimeDistributed(Dense(100)))
model.add(Flatten())
# Output- Layer
model.add(Dense(units=1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 300)           7695600
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 25, 120)           173280
# _________________________________________________________________
# time_distributed (TimeDistri (None, 25, 100)           12100
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2500)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 2501
# =================================================================
# Total params: 7,883,481
# Trainable params: 7,883,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
print('training_sentences : ',hl_train_data_pad.shape)
print('testing_sentences : ',hl_test_data_pad.shape)
print('training_labels : ',training_labels.shape)
print('testing_labels : ',testing_labels.shape)
# Out:
# training_sentences :  (20032, 25)
# testing_sentences :  (6677, 25)
# training_labels :  (20032,)
# testing_labels :  (6677,)

# %% [markdown]
# ## Compile the model

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 300)           7695600
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 25, 120)           173280
# _________________________________________________________________
# time_distributed (TimeDistri (None, 25, 100)           12100
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2500)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 2501
# =================================================================
# Total params: 7,883,481
# Trainable params: 7,883,481
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fit the model

# %%
# Converting the lists to numpy arrays for Tensorflow 2.x
training_padded = np.array(hl_train_data_pad)
training_labels = np.array(training_labels)
testing_padded = np.array(hl_test_data_pad)
testing_labels = np.array(testing_labels)
# Training the model
num_epochs = 30
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Epoch 1/30
# 626/626 - 73s - loss: 0.3766 - accuracy: 0.8267 - val_loss: 0.3102 - val_accuracy: 0.8652
# Epoch 2/30
# 626/626 - 71s - loss: 0.1874 - accuracy: 0.9250 - val_loss: 0.3305 - val_accuracy: 0.8624
# Epoch 3/30
# 626/626 - 70s - loss: 0.0877 - accuracy: 0.9677 - val_loss: 0.4619 - val_accuracy: 0.8585
# Epoch 4/30
# 626/626 - 69s - loss: 0.0352 - accuracy: 0.9876 - val_loss: 0.5716 - val_accuracy: 0.8532
# Epoch 5/30
# 626/626 - 70s - loss: 0.0151 - accuracy: 0.9952 - val_loss: 0.8231 - val_accuracy: 0.8559
# Epoch 6/30
# 626/626 - 69s - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.8173 - val_accuracy: 0.8523
# Epoch 7/30
# 626/626 - 68s - loss: 0.0099 - accuracy: 0.9965 - val_loss: 1.0125 - val_accuracy: 0.8507
# Epoch 8/30
# 626/626 - 70s - loss: 0.0070 - accuracy: 0.9977 - val_loss: 1.2003 - val_accuracy: 0.8538
# Epoch 9/30
# 626/626 - 69s - loss: 0.0099 - accuracy: 0.9965 - val_loss: 1.0109 - val_accuracy: 0.8450
# Epoch 10/30
# 626/626 - 69s - loss: 0.0075 - accuracy: 0.9973 - val_loss: 1.1264 - val_accuracy: 0.8579
# Epoch 11/30
# 626/626 - 71s - loss: 0.0065 - accuracy: 0.9977 - val_loss: 1.1884 - val_accuracy: 0.8532
# Epoch 12/30
# 626/626 - 69s - loss: 0.0020 - accuracy: 0.9992 - val_loss: 1.3277 - val_accuracy: 0.8549
# Epoch 13/30
# 626/626 - 69s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 1.3781 - val_accuracy: 0.8529
# Epoch 14/30
# 626/626 - 71s - loss: 0.0038 - accuracy: 0.9988 - val_loss: 1.3162 - val_accuracy: 0.8463
# Epoch 15/30
# 626/626 - 69s - loss: 0.0058 - accuracy: 0.9979 - val_loss: 1.4293 - val_accuracy: 0.8508
# Epoch 16/30
# 626/626 - 69s - loss: 0.0047 - accuracy: 0.9984 - val_loss: 1.3341 - val_accuracy: 0.8516
# Epoch 17/30
# 626/626 - 70s - loss: 0.0031 - accuracy: 0.9988 - val_loss: 1.5986 - val_accuracy: 0.8484
# Epoch 18/30
# 626/626 - 69s - loss: 0.0051 - accuracy: 0.9982 - val_loss: 1.4933 - val_accuracy: 0.8480
# Epoch 19/30
# 626/626 - 69s - loss: 0.0022 - accuracy: 0.9992 - val_loss: 1.5706 - val_accuracy: 0.8490
# Epoch 20/30
# 626/626 - 70s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 1.5210 - val_accuracy: 0.8469
# Epoch 21/30
# 626/626 - 69s - loss: 0.0026 - accuracy: 0.9990 - val_loss: 1.7697 - val_accuracy: 0.8445
# Epoch 22/30
# 626/626 - 71s - loss: 0.0034 - accuracy: 0.9989 - val_loss: 1.7490 - val_accuracy: 0.8489
# Epoch 23/30
# 626/626 - 71s - loss: 0.0024 - accuracy: 0.9990 - val_loss: 1.9541 - val_accuracy: 0.8526
# Epoch 24/30
# 626/626 - 71s - loss: 0.0028 - accuracy: 0.9989 - val_loss: 1.8025 - val_accuracy: 0.8540
# Epoch 25/30
# 626/626 - 70s - loss: 0.0013 - accuracy: 0.9994 - val_loss: 1.8073 - val_accuracy: 0.8471
# Epoch 26/30
# 626/626 - 69s - loss: 5.8920e-04 - accuracy: 0.9996 - val_loss: 1.7827 - val_accuracy: 0.8478
# Epoch 27/30
# 626/626 - 71s - loss: 6.0051e-04 - accuracy: 0.9997 - val_loss: 2.1150 - val_accuracy: 0.8474
# Epoch 28/30
# 626/626 - 69s - loss: 0.0083 - accuracy: 0.9984 - val_loss: 1.9778 - val_accuracy: 0.8495
# Epoch 29/30
# 626/626 - 70s - loss: 0.0042 - accuracy: 0.9986 - val_loss: 1.8919 - val_accuracy: 0.8454
# Epoch 30/30
# 626/626 - 70s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 1.8523 - val_accuracy: 0.8411

# %%
sentence = ["Coworkers At Bathroom Sink Locked In Tense Standoff Over Who Going To Wash Hands Longer", 
            "Spiking U.S. coronavirus cases could force rationing decisions similar to those made in Italy, China."]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=maxlen)
print(model.predict(padded))
# Out:
# [[1.        ]
#  [0.07241046]]

# %%
print("Test-Accuracy:", np.mean(history.history["val_accuracy"]))
# Out:
# Test-Accuracy: 0.8511806646982829

# %% [markdown]
# ## Check the validation accuracy

# %%
scores = model.evaluate(testing_padded, testing_labels, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 84.11%
